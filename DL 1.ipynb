# %% [markdown]
# 1. What is the function of a summation junction of a neuron? What is threshold activation
# function?

# %% [markdown]
# A summation junction for the input signals is weighted by the respective synaptic weight.Because it is a linear combiner
# or adder of the weighted input signals,the output of the summation junction can be expressed as follows:
#
#    Y(sum)=(summation)W(i)X(i)

# %% [markdown]
# A threshold activation function(or simply the activation function,also known as squashing function) result in an
# output signal only when an input signal exceeding a specific threshold value comes as an input.It is similar in
# behaviour to the biological neuron which transmits the signal only when the total input signal meets the firing
# threshold.

# %% [markdown]
# 2. What is a step function? What is the difference of step function with threshold function?

# %% [markdown]
# Step Function is one of the simplest kind of activation function.In this, we consider a threshold value and if the
# value of net input say y is greater than the threshold then the neuron is activated.
# Mathematically,
#
#      f(x)=1, if x>=0
#      f(x)=0, if x<0

# %% [markdown]
# ![1dl.png](attachment:96965919-d4d7-4678-9f37-7cdf54084ff0.png)

# %% [markdown]
# 3. Explain the McCulloch–Pitts model of neuron.

# %% [markdown]
# The motivation behind the McCulloh Pitts's Model is a bilogical neuron. A biological neuron takes an input signal from
# the dendrites  and after processing it passes onto other connected neurons as the output if the signal is received
# positively, through axons and synapses.

# %% [markdown]
# 4. Explain the ADALINE network model.

# %% [markdown]
# MADALINE (Many ADALINE) is a three-layer (input,hidden,output), fully connected, feed-forward artificial neural network
# architecture for classification that uses ADALINE units in its hidden and output layers,i.e its activation function is
# the sign function.The three-layer network uses memistors

# %% [markdown]
# 5. What is the constraint of a simple perceptron? Why it may fail with a real-world data set?

# %% [markdown]
# Perceptron networks should be trained with adapt, which presents the input vectors to the network one at a time and makes
# corrections to the network based on the results of each presentation. Use of adapt in this way guarantees that any
# linearly separable problem is solved in a finite number of training presentations. Perceptrons can also be trained with
# the function train, which is presented in the next chapter. When train is used for perceptrons, it presents the inputs to
# the network in batches, and makes corrections to the network based on the sum of all the individual corrections.
# Unfortunately, there is to proof that such a training algorithum converges for perceptrons.On that account the use of
# train for perceptrons is not recommended.

# %% [markdown]
# Perceptron networks have several limitations. First, the output values of a perceptron can take on only one of two values (0 or 1) due to the hard-limit transfer function. Second, perceptrons can only classify linearly separable sets of vectors. If a straight line or a plane can be drawn to separate the input vectors into their correct categories, the input vectors are linearly separable. If the vectors are not linearly separable, learning will never reach a point where all vectors are classified properly. Note, however, that it has been proven that if the vectors are linearly separable, perceptrons trained adaptively will always find a solution in finite time. You might want to try demop6. It shows the difficulty of trying to classify input vectors that are not linearly separable.

# %% [markdown]
# 6. What is linearly inseparable problem? What is the role of the hidden layer?

# %% [markdown]
# Clearly not all decision problems are lineraly seperable:
#
#     They cannot be solved using a linear decision boundary.Problems like these are termed lineraly inseperable. XOR is a
#     linearly inseparable problem.
#     If you don't understand the concept of linear seperability and inseperability try plotting points in the input space in
#     the demonstration below.Then try and separate the two classes by altering the position of the decision boundaryby hand.

# %% [markdown]
# Hidden layer(s) are the secret sauce of your network. Thet allow you to model complex data thanks to their nodes/neurons.
# They are "hidden" because the true values of their nodes are unknown in the training dataset. In fact, we only know the
# input and output.

# %% [markdown]
# 7. Explain XOR problem in case of a simple perceptron.

# %% [markdown]
# The XOr problem is that we need to build a Neural Network (a perceptron  in our case) to produce the truth table related
# to the XOr logical operator.This is a binary classification problem. Hence, supervised learning is a better way to solve
# it. In this case, we will be using perceptrons.

# %% [markdown]
# 8. Design a multi-layer perceptron to implement A XOR B.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
xor_data=pd.DataFrame()
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]
sns.scatterplot(xor_data['input1'],xor_data['input2'],hue=xor_data['ouput'],s=200)
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf1.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [2], line 9
#       7 xor_data['input2']=[1,0,1,0]
#       8 xor_data['ouput']=[0,1,1,0]
# ----> 9 sns.scatterplot(xor_data['input1'],xor_data['input2'],hue=xor_data['ouput'],s=200)
#      10 from sklearn.linear_model import Perceptron
#      11 clf1=Perceptron()
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %% [markdown]
# 9. Explain the single-layer feed forward architecture of ANN.

# %% [markdown]
# In this type of network, we have only two layers input layer and the output layer but the input layer does not count
# because no computation is performed in this layer. The output layer is formed when different weights are applied to input
# nodes and the cumulative effect per node is taken. After this, the neurons collectively give the output layer to compute
# the output signals.

# %% [markdown]
# ![image.png](attachment:c92a7581-0ec9-4de2-83ea-1fa6e3251bd3.png)

# %% [markdown]
# 10. Explain the competitive network architecture of ANN.

# %% [markdown]
# An Artificial Neural Network(ANN) is an information processing paradigm that is inspired by the brain. ANNs, like
# people, learn by examples. An ANN is configured for a specific application, such as pattern recognition or data
# classification, through a learning process. Learning largely involves adjustments to the synaptic connections that exist
# between the neurons.

# %% [markdown]
# 11. Consider a multi-layer feed forward neural network. Enumerate and explain steps in the
# backpropagation algorithm used to train the network.

# %% [markdown]
# Backpropagation is a widely used algorithum for training feedforward neural networks.It computes the gradient of the loss
# function with respect to the netowrk weights and is very efficient, rather than naively directly computing the gradient
# with respect to each individual weight. This efficiency makes it possible to use gradient methods to train multi-layer
# networks and update weights to minimize loss, variants such as gradient descent or stochastic gradient descent are often
# used.
#
# The backpropagation algorithum works by computing the gradient of the loss function with respect to each weight via the
# chain rule, computing the gradient layer by layer, and iterating backward from  the last layer to avoid redundant
# computation of intermediate terms in the chain rule.
#
# Working of Backpropagation:
#
#     Neural network use supervised learning to generate output vectors from input vectors that the network operates on.Itcompares generated output to the desired output and generates an error report of the result does not match the generated output generated output to the desired output and generates an error report if the result does not match the generated output vector. Then it adjusts the weights according to the bug report to get your desired output.

# %% [markdown]
# 12. What are the advantages and disadvantages of neural networks?

# %% [markdown]
# The key advantages of neural networks are as follows:
#
#     Efficienncy
#     Continuous Learning
#     Data retrieval
#     Multitasking is one of the common advantages of Neural Networks
#     Wide Applictions
#     Hardware dependent
#     Complex Algorithims are forsseen disadvantages of Natural Networks
#     BlackBox Nature
#
# Disadvantages of Neural Networks:
#
#     Black Box
#     Duration of Devolopment
#     Amount of data
#     Computatuionally Expensive.

# %% [markdown]
# 13. Write short notes on any two of the following:
#
#     1. Biological neuron
#     2. ReLU function
#     3. Single-layer feed forward ANN
#     4. Gradient descent
#     5. Recurerent networks

# %% [markdown]
# 2.
# In a neural network, the activation function is responsible for transforming the summed weighted input from the node into
# the activation of the node or output for that input .
# The rectified linear actication function or ReLU for short is a piecewise linear function that will output the input
# directly if it a positive, otherwise, it will output zero.It has become the default activation function for many types
# of neural if it is positive, otherwise, it will output zero.It has become the default activation function for many types
# of neural networks because a model that uses it is easier to train and often achieves better performance.

# %% [markdown]
# 3.
# In this type of network, we have only two layers input layer and the output layer but the input layer does not count
# because no computation is performed in this layer .The output layer is formed when different weights are applied to input
# nodes and the cumulative effect per node is taken. After this , the neurons collectively give the output layer to compute
# the output signals.

# %% [markdown]
# ![image.png](attachment:2517e344-91fa-4df9-b586-15942fcb859b.png)
